# %%
# importando bibioteca pandas
import pandas as pd

# %%
# lendo um arquivo de csv
# criando uma variavel
arq = pd.read_csv('data_teste.csv', sep=';')
arq
# Out:
#     Data Venda    Cliente      Cidade   Produto  Prazo Pgto Prç Unt./Kg  \
# 0   05/01/2012  Carrefour   São Paulo       Sal           0        2,77
# 1   05/01/2012      Sonda     Barueri     Trigo           0        5,56
# 2   25/01/2012  Carrefour     Diadema     Trigo           0        5,56
# 3   25/01/2012      Extra      Santos  Macarrão           0       10,08
# 4   08/02/2012  Carrefour     Diadema    Cevada           0        2,60
# ..         ...        ...         ...       ...         ...         ...
# 91  06/08/2012        Big   São Paulo    Feijao          45        7,04
# 92  06/08/2012        Big  S. Caetano    Açucar          45        9,87
# 93  27/08/2012      Extra     Diadema    Feijao          45        7,04
# 94  06/08/2012  Carrefour   São Paulo     Trigo          90        6,51
# 95  26/08/2012  Carrefour   São Paulo     Trigo          90        5,56
#
#     Volume kg         Valor Vendedor
# 0         460      R$ 54,00   Amanda
# ...

# %%
#Análisando o tipo de cada coluna
arq.dtypes
# Out:
# Data Venda     object
# Cliente        object
# Cidade         object
# Produto        object
# Prazo Pgto      int64
# Prç Unt./Kg    object
# Volume kg       int64
# Valor          object
# Vendedor       object
# dtype: object

# %%
#Convertendo objeto da coluna valor para numero
arq['Valor'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-83f91f84171d> in <module>
#       1 #Convertendo objeto da coluna valor para numero
# ----> 2 arq['Valor'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
#Análisando a informação de cada coula
arq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Data Venda   96 non-null     object
#  1   Cliente      96 non-null     object
#  2   Cidade       96 non-null     object
#  3   Produto      96 non-null     object
#  4   Prazo Pgto   96 non-null     int64
#  5   Prç Unt./Kg  96 non-null     object
#  6   Volume kg    96 non-null     int64
#  7   Valor        96 non-null     object
#  8   Vendedor     96 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 6.9+ KB

# %%
#Análisando as 5 primeiras linhas
arq.head()
# Out:
#    Data Venda    Cliente     Cidade   Produto  Prazo Pgto Prç Unt./Kg  \
# 0  05/01/2012  Carrefour  São Paulo       Sal           0        2,77
# 1  05/01/2012      Sonda    Barueri     Trigo           0        5,56
# 2  25/01/2012  Carrefour    Diadema     Trigo           0        5,56
# 3  25/01/2012      Extra     Santos  Macarrão           0       10,08
# 4  08/02/2012  Carrefour    Diadema    Cevada           0        2,60
#
#    Volume kg         Valor Vendedor
# 0        460      R$ 54,00   Amanda
# 1        750  R$ 14.170,00  Luciana
# 2        100     R$ 556,00    Katia
# 3         10     R$ 100,80  Rodrigo
# 4        600   R$ 1.560,00  Rodrigo

# %%
#Analisando as 5 ultimas linhas
arq.tail()
# Out:
#     Data Venda    Cliente      Cidade Produto  Prazo Pgto Prç Unt./Kg  \
# 91  06/08/2012        Big   São Paulo  Feijao          45        7,04
# 92  06/08/2012        Big  S. Caetano  Açucar          45        9,87
# 93  27/08/2012      Extra     Diadema  Feijao          45        7,04
# 94  06/08/2012  Carrefour   São Paulo   Trigo          90        6,51
# 95  26/08/2012  Carrefour   São Paulo   Trigo          90        5,56
#
#     Volume kg        Valor Vendedor
# 91        800    R$ 454,00  Eduardo
# 92        454  R$ 4.482,00  Eduardo
# 93        300  R$ 2.112,00  Rodrigo
# 94        100    R$ 100,00  Luciana
# 95        600  R$ 3.336,00  Luciana

# %%
# formatando a tabela de valores
arq['Valor'] = arq['Valor'].apply(lambda x: str(x).replace(',','.'))
# Troca o R$ por aspas vazias
arq['Valor'] = arq['Valor'].apply(lambda x: str(x).replace('R$ ',' '))

# %%
arq['Valor']
# Out:
# 0          54.00
# 1      14.170.00
# 2         556.00
# 3         100.80
# 4       1.560.00
#          ...
# 91        454.00
# 92      4.482.00
# 93      2.112.00
# 94        100.00
# 95      3.336.00
# Name: Valor, Length: 96, dtype: object

# %%
arq['Valor'] = arq['Valor'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-88c1723056a6> in <module>
# ----> 1 arq['Valor'] = arq['Valor'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...
